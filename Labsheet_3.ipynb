# %%
import pandas as pd

# %%
df = pd.read_csv("/content/EMP.csv")
df.head()
# Out:
#    Empid    Ename  Salary         Doj
# 0   1001    Jacky    8500  10/03/2002
# 1   1002    Jenny    7500  15/06/2003
# 2   1003   Joseph    6500  01/04/2004
# 3   1004  Michael    9500   20/2/2000
# 4   1005  Pradeep    4500  25/08/2005

# %%
df.tail(2)
# Out:
#    Empid    Ename  Salary         Doj
# 3   1004  Michael    9500   20/2/2000
# 4   1005  Pradeep    4500  25/08/2005

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empid   5 non-null      int64
#  1   Ename   5 non-null      object
#  2   Salary  5 non-null      int64
#  3   Doj     5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
df.describe()
# Out:
#              Empid       Salary
# count     5.000000     5.000000
# mean   1003.000000  7300.000000
# std       1.581139  1923.538406
# min    1001.000000  4500.000000
# 25%    1002.000000  6500.000000
# 50%    1003.000000  7500.000000
# 75%    1004.000000  8500.000000
# max    1005.000000  9500.000000

# %%
df.shape
# Out:
# (5, 4)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Empid', 'Ename', 'Salary', 'Doj'], dtype='object')

# %%
df.Empid
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# Name: Empid, dtype: int64

# %%
df[['Empid','Ename']]
# Out:
#    Empid    Ename
# 0   1001    Jacky
# 1   1002    Jenny
# 2   1003   Joseph
# 3   1004  Michael
# 4   1005  Pradeep

# %%
df1 = df.append(df)
print('Dimensions of the original frame',df.shape)
print('Dimensions of the frame with duplicates',df1.shape)
df1 = df1.drop_duplicates()
print('Dimensions of the frame after deleting duplicates', df1.shape)
# Out:
# Dimensions of the original frame (5, 4)
# Dimensions of the frame with duplicates (10, 4)
# Dimensions of the frame after deleting duplicates (5, 4)
# <ipython-input-16-7f0059cdb450>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df.append(df)

# %%
df.columns = [i.upper() for i in df]
print(df.columns)
# Out:
# Index(['EMPID', 'ENAME', 'SALARY', 'DOJ'], dtype='object')

# %%
df.isna().sum()
# Out:
# EMPID     0
# ENAME     0
# SALARY    0
# DOJ       0
# dtype: int64

# %%
print('The no. of nulls in each column is \n', df.isnull().sum())
df.dropna(axis = 1, inplace = False)
# Out:
# The no. of nulls in each column is
#  EMPID     0
# ENAME     0
# SALARY    0
# DOJ       0
# dtype: int64
#    EMPID    ENAME  SALARY         DOJ
# 0   1001    Jacky    8500  10/03/2002
# 1   1002    Jenny    7500  15/06/2003
# 2   1003   Joseph    6500  01/04/2004
# 3   1004  Michael    9500   20/2/2000
# 4   1005  Pradeep    4500  25/08/2005

# %%
df.isna().sum()
# Out:
# EMPID     0
# ENAME     0
# SALARY    0
# DOJ       0
# dtype: int64

# %%
print('Highset Salary is: ',df['SALARY'].max())
print('Lowest Salary is: ',df['SALARY'].min())
# Out:
# Highset Salary is:  9500
# Lowest Salary is:  4500

# %%
df[df.SALARY > 7000 ]
# Out:
#    EMPID    ENAME  SALARY         DOJ
# 0   1001    Jacky    8500  10/03/2002
# 1   1002    Jenny    7500  15/06/2003
# 3   1004  Michael    9500   20/2/2000

# %%
df[['EMPID','ENAME']][df.SALARY > 8000]
# Out:
#    EMPID    ENAME
# 0   1001    Jacky
# 3   1004  Michael

# %%
df[['EMPID','ENAME']][df.SALARY == df.SALARY.max()]
# Out:
#    EMPID    ENAME
# 3   1004  Michael

# %%
print('Average Salary is', df.SALARY.mean())
df['ENAME'][df.SALARY > df.SALARY.mean()]
# Out:
# Average Salary is 7300.0
# 0      Jacky
# 1      Jenny
# 3    Michael
# Name: ENAME, dtype: object

# %%
df1['Doj'] = pd.to_datetime(df1['Doj'])
df1.info()
print('Frame before sorting\n', df1)
df1.sort_values("Doj", inplace = True)
print('Frame after sorting\n', df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empid   5 non-null      int64
#  1   Ename   5 non-null      object
#  2   Salary  5 non-null      int64
#  3   Doj     5 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 200.0+ bytes
# Frame before sorting
#     Empid    Ename  Salary        Doj
# 0   1001    Jacky    8500 2002-10-03
# 1   1002    Jenny    7500 2003-06-15
# 2   1003   Joseph    6500 2004-01-04
# 3   1004  Michael    9500 2000-02-20
# 4   1005  Pradeep    4500 2005-08-25
# Frame after sorting
#     Empid    Ename  Salary        Doj
# 3   1004  Michael    9500 2000-02-20
# 0   1001    Jacky    8500 2002-10-03
# 1   1002    Jenny    7500 2003-06-15
# 2   1003   Joseph    6500 2004-01-04
# 4   1005  Pradeep    4500 2005-08-25
# <ipython-input-27-cc9cecc9689e>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df1['Doj'] = pd.to_datetime(df1['Doj'])

# %%
df1.sort_values("Doj", ascending = False, inplace = True)
df1
# Out:
#    Empid    Ename  Salary        Doj
# 4   1005  Pradeep    4500 2005-08-25
# 2   1003   Joseph    6500 2004-01-04
# 1   1002    Jenny    7500 2003-06-15
# 0   1001    Jacky    8500 2002-10-03
# 3   1004  Michael    9500 2000-02-20

# %%
df1.sort_values(by = ['Doj', 'Salary'], ascending = [False,True], inplace = True)
df1
# Out:
#    Empid    Ename  Salary        Doj
# 4   1005  Pradeep    4500 2005-08-25
# 2   1003   Joseph    6500 2004-01-04
# 1   1002    Jenny    7500 2003-06-15
# 0   1001    Jacky    8500 2002-10-03
# 3   1004  Michael    9500 2000-02-20
